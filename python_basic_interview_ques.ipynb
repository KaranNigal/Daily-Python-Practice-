# %%
# 1. print hello world
print('hello world')
print('hello world')
print('hello world')
print('hello world')
# Out:
# hello world
# hello world
# hello world
# hello world

# %%
# 2. print sum of 2 numbers  
n1= int(input('Enter number 1: '))
n2= int(input('Enter number 2:'))
sum = n1 + n2
print('the sum of numbers is',sum)
# Out:
# the sum of numbers is 40

# %%
# 3. print diff of 2 numbers  
n1= int(input('Enter number 1: '))
n2= int(input('Enter number 2:'))
diff = n1 - n2
print('the sum of numbers is',diff)
# Out:
# the sum of numbers is 30

# %%
# 4. demonstrate calculator operation like sum, diff, mul, div
n1= int(input('enter number 1'))
n2= int(input('enter number 2'))

print('the sum is:', n1+n2)
print('the diff is:', n1-n2)
print('the product is:', n1*n2)
print('the division is:', n1/n2)
# Out:
# the sum is: 80
# the diff is: 20
# the product is: 1500
# the division is: 1.6666666666666667

# %%
# 5. wp to check if a number is even or odd
n= int(input('enter the number'))

if (n%2==0):
    print('the number is even')
else:
    print('the number is odd')
# Out:
# the number is odd
