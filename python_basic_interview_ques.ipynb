# %%
# 1. print hello world
print('hello world')
print('hello world')
print('hello world')
print('hello world')
# Out:
# hello world
# hello world
# hello world
# hello world

# %%
# 2. print sum of 2 numbers  
n1= int(input('Enter number 1: '))
n2= int(input('Enter number 2:'))
sum = n1 + n2
print('the sum of numbers is',sum)
# Out:
# the sum of numbers is 40

# %%
# 3. print diff of 2 numbers  
n1= int(input('Enter number 1: '))
n2= int(input('Enter number 2:'))
diff = n1 - n2
print('the sum of numbers is',diff)
# Out:
# the sum of numbers is 30

# %%
# 4. demonstrate calculator operation like sum, diff, mul, div
n1= int(input('enter number 1'))
n2= int(input('enter number 2'))

print('the sum is:', n1+n2)
print('the diff is:', n1-n2)
print('the product is:', n1*n2)
print('the division is:', n1/n2)
# Out:
# the sum is: 80
# the diff is: 20
# the product is: 1500
# the division is: 1.6666666666666667

# %%
# 5. wp to check if a number is even or odd
n= int(input('enter the number'))

if (n%2==0):
    print('the number is even')
else:
    print('the number is odd')
# Out:
# the number is odd

# %%
# 6. write a program to return the maximum of two numbers 
n1= int(input('enter the first number'))
n2= int(input('enter the second number'))

greater= max(n1,n2)

print('the max number is', greater)
# Out:
# the max number is 50

# %%
# 7. wp to check if a number is prime or not 

n= int(input('enter the number to check if its prime or not '))

if n>1:
    for i in range(1, int(n**1/2)):
        if(n%i==0):
            print('the number is not prime')
            break
        else:
            print('the number is prime')
else:
    print('enter valid number')
# Out:
# the number is not prime

# %%
# 8.  Write a Python factorial program without using if-else, for, and ternary operators. 
import math

def factorial(num):
    return math.factorial(num)

num= int(input('enter the number to return factorial'))
f1=factorial(num)

print('the factorial is: ', f1)
# Out:
# the factorial is:  24

# %%
# 9. Write a Python program to calculate the square root of a given number.

n= int(input('enter the number to find the sq root'))
sqrt= n**0.5
print(f'the sqrt of {n} is {sqrt}')
# Out:
# the sqrt of 81 is 9.0

# %%
# 10.  Write a Python program to calculate the area of a triangle.

s1= int(input('enter the first side'))
s2= int(input('enter the second side'))
s3= int(input('enter the third side'))

s= (s1+s2+s3)/2

area= (s*(s-s1)*(s-s2)*(s-s3))**0.5

print('area of the triangle is: ',area)
# Out:
# area of the triangle is:  290.4737509655563
